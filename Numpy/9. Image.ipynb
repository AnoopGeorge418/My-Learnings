# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = plt.imread('./Images/goal.png')
im.shape
# Out:
# (804, 1626, 4)

# %%
plt.imshow(im)

# %%
im3 = im[:, :, 0:3]

# %%
plt.imshow(im3)

# %%
im3.shape
# Out:
# (804, 1626, 3)

# %%
img = im3

# %%
r = img[:, :, 0]
r.shape
# Out:
# (804, 1626)

# %%
fig, ax = plt.subplots(1, 3)
img2 = img.copy()
img2[:, :, 2] = 200
ch = ['Red', 'Green', 'Blue']
for i, axi in enumerate(ax.flat):
    axi.imshow(img2[:, :, i], plt.cm.gray)
    axi.set(xticks=[], yticks=[])
    axi.set_xlabel(ch[i], color = ch[i].lower())
    fig.set_size_inches(20, 50)

# %%
img2[:, :, 2] = 200
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img2 = img.copy()
img2[400:1000, 400:1000, 1] = 255
img2[400:1000, 400:1000, 0] = 0
img2[400:1000, 400:1000, 2] = 0
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img2 = img.copy()
plt.imshow(img2)

# %%
idx = np.arange(img2.shape[1])
img3 = img2[:, idx[::-1], :]
plt.imshow(img3)

# %%
plt.imshow(img3[np.arange(img3.shape[0])[::-1], :, :])

# %%
img = plt.imread('./Images/goal.png')
plt.imshow(img)

# %%
img2 = img.copy()
img2[100:500, 1000:2000, 0] = 0 #r
img2[100:500, 1000:2000, 1] = 0 #g
img2[100:500, 1000:2000, 2] = 200 #b
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
