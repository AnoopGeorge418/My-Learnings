# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.

# %%
import logging

def basic_logger():
    logging.basicConfig(filename='app.log', level=logging.DEBUG)
    logging.debug('This is a debug message')
    logging.info('This is an info message')
    logging.warning('This is a warning message')
    logging.error('This is an error message')
    logging.critical('This is a critical message')

# Test the function
basic_logger()

# %% [markdown]
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

# %%
def logger_with_handlers():
    logger = logging.getLogger('my_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('app.log')
    console_handler = logging.StreamHandler()
    
    file_handler.setLevel(logging.DEBUG)
    console_handler.setLevel(logging.DEBUG)
    
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_handlers()
# Out:
# 2024-08-30 22:37:29,607 - my_logger - DEBUG - This is a debug message
# 2024-08-30 22:37:29,609 - my_logger - INFO - This is an info message
# 2024-08-30 22:37:29,614 - my_logger - WARNING - This is a warning message
# 2024-08-30 22:37:29,617 - my_logger - ERROR - This is an error message
# 2024-08-30 22:37:29,619 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different logging levels for the file and console handlers.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

# %%
def logger_with_custom_format():
    logger = logging.getLogger('custom_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('custom_app.log')
    console_handler = logging.StreamHandler()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_custom_format()
# Out:
# 2024-08-30 22:37:35,527 - DEBUG - This is a debug message
# 2024-08-30 22:37:35,529 - INFO - This is an info message
# 2024-08-30 22:37:35,531 - WARNING - This is a warning message
# 2024-08-30 22:37:35,534 - ERROR - This is an error message
# 2024-08-30 22:37:35,536 - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different formats for the file and console handlers.

# %%
def logger_with_different_formats():
    logger = logging.getLogger('multi_format_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('multi_format_app.log')
    console_handler = logging.StreamHandler()
    
    file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(file_formatter)
    console_handler.setFormatter(console_formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_different_formats()
# Out:
# 2024-08-30 22:37:42,599 - DEBUG - This is a debug message
# 2024-08-30 22:37:42,602 - INFO - This is an info message
# 2024-08-30 22:37:42,603 - WARNING - This is a warning message
# 2024-08-30 22:37:42,608 - ERROR - This is an error message
# 2024-08-30 22:37:42,610 - CRITICAL - This is a critical message

# %% [markdown]
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.

# %%
from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
    logger = logging.getLogger('rotating_logger')
    logger.setLevel(logging.DEBUG)
    
    rotating_handler = RotatingFileHandler('rotating_app.log', maxBytes=2000, backupCount=5)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    rotating_handler.setFormatter(formatter)
    
    logger.addHandler(rotating_handler)
    
    for i in range(100):
        logger.debug('This is debug message number {}'.format(i))

# Test the function
logger_with_rotating_file_handler()

# %% [markdown]
# 2. Modify the function to keep a specified number of backup log files.

# %%
# The modification is already included in the above function with backupCount=5.

# %% [markdown]
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.

# %%
def log_exception():
    logger = logging.getLogger('exception_logger')
    logger.setLevel(logging.ERROR)
    
    file_handler = logging.FileHandler('exception_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    try:
        1 / 0
    except Exception as e:
        logger.exception("An exception occurred")

# Test the function
log_exception()

# %% [markdown]
# 2. Modify the function to log the stack trace at the ERROR level.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.

# %%
def logger_with_context():
    logger = logging.getLogger('context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    def test_func():
        logger.debug('This is a debug message')
        logger.info('This is an info message')
        logger.warning('This is a warning message')
        logger.error('This is an error message')
        logger.critical('This is a critical message')
    
    test_func()

# Test the function
logger_with_context()

# %% [markdown]
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).

# %%
def logger_with_additional_context(user_id, session_id):
    logger = logging.getLogger('additional_context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('additional_context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d - UserID: %(user_id)s - SessionID: %(session_id)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    extra = {'user_id': user_id, 'session_id': session_id}
    
    def test_func():
        logger.debug('This is a debug message', extra=extra)
        logger.info('This is an info message', extra=extra)
        logger.warning('This is a warning message', extra=extra)
        logger.error('This is an error message', extra=extra)
        logger.critical('This is a critical message', extra=extra)
    
    test_func()

# Test the function
logger_with_additional_context('user123', 'session456')

# %% [markdown]
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.

# %%
import logging.config

def configure_logging_with_dict():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            },
            'detailed': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'dict_config_app.log',
                'formatter': 'detailed',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)
    logger = logging.getLogger('')
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
configure_logging_with_dict()
# Out:
# 2024-08-30 22:37:55,480 - root - DEBUG - This is a debug message
# 2024-08-30 22:37:55,483 - root - INFO - This is an info message
# 2024-08-30 22:37:55,488 - root - WARNING - This is a warning message
# 2024-08-30 22:37:55,490 - root - ERROR - This is an error message
# 2024-08-30 22:37:55,492 - root - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the dictionary to include different logging levels and formats for each handler.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.

# %% [markdown]
# #### File: `main.py`

# %%
import logging
from module_a import module_a_function
from module_b import module_b_function

def setup_logging():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'multi_module_app.log',
                'formatter': 'default',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)

# Main script
if __name__ == '__main__':
    setup_logging()
    logger = logging.getLogger(__name__)
    logger.info('Main module started')
    module_a_function()
    module_b_function()
    logger.info('Main module finished')

# %% [markdown]
# #### File: `module_a.py`

# %%
import logging

def module_a_function():
    logger = logging.getLogger(__name__)
    logger.info('Module A function started')
    logger.debug('This is a debug message from Module A')
    logger.info('Module A function finished')

# %% [markdown]
# #### File: `module_b.py`

# %%
import logging

def module_b_function():
    logger = logging.getLogger(__name__)
    logger.info('Module B function started')
    logger.debug('This is a debug message from Module B')
    logger.info('Module B function finished')

# %% [markdown]
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.

# %%
# The modification is already included in the above scripts. Each module's logger messages propagate to the root logger.

# %% [markdown]
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).

# %%
import logging
import time
from logging.handlers import RotatingFileHandler

def benchmark_logging_performance():
    logger = logging.getLogger('performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler
    file_handler = logging.FileHandler('performance_file.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # Console handler
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.DEBUG)
    logger.addHandler(console_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Console handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(console_handler)

    # Rotating file handler
    rotating_handler = RotatingFileHandler('performance_rotating.log', maxBytes=2000, backupCount=5)
    rotating_handler.setLevel(logging.DEBUG)
    logger.addHandler(rotating_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Rotating file handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(rotating_handler)

# Test the function
benchmark_logging_performance()
# Out:
# 2024-08-30 22:38:08,176 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,182 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,185 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,189 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,190 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,192 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,196 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,199 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,202 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,204 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,207 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,209 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,211 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,214 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,216 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,218 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,220 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,223 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,224 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,226 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,228 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,230 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,231 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,236 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,238 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,239 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,240 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,243 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,246 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,248 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,250 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,252 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,254 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,254 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,254 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,254 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,254 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,265 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,267 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,271 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,273 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,276 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,276 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,276 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,287 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,291 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,293 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,293 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,293 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,293 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,304 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,306 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,308 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,310 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,312 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,314 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,316 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,327 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,329 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,332 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,334 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,335 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,337 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,342 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,345 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,348 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,354 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,357 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,362 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,363 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,366 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,370 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,372 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,375 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,377 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,380 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,383 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,386 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,388 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,390 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,393 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,395 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,397 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,399 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,402 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,404 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,405 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,408 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,410 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,412 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,414 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,416 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,420 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,422 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,425 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,427 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,428 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,430 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,432 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,438 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,446 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,447 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,452 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,458 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,460 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,463 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,465 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,471 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,473 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,477 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,479 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,481 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,488 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,492 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,495 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,498 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,505 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,508 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,510 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,513 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,520 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,524 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,526 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,530 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,534 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,536 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,538 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,540 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,543 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,545 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,546 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,552 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,555 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,558 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,560 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,566 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,569 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,572 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,576 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,581 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,584 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,592 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,596 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,597 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,604 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,606 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,610 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,614 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,616 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,620 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,621 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,626 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,628 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,630 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,633 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,636 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,641 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,644 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,646 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,648 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,652 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,654 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,657 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,662 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,664 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,665 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,670 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,672 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,674 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,677 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,680 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,682 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,688 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,693 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,695 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,701 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,706 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,708 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,712 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,715 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,721 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,724 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,725 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,728 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,731 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,735 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,739 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,744 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,748 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,751 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,754 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,758 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,760 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,762 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,765 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,767 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,770 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,773 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,775 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,777 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,779 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,782 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,783 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,786 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,788 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,790 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,792 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,794 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,796 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,800 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,803 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,806 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,810 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,815 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,821 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,826 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,831 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,837 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,842 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,845 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,848 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,856 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,860 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,863 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,870 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,872 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,877 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,880 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,881 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,889 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,893 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,895 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,897 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,897 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,904 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,907 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,909 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,912 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,914 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,918 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,922 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,925 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,927 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,930 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,934 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,936 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,942 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,944 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,947 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,954 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,956 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,963 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,965 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,971 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,976 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,978 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,978 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,984 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,988 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,990 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,992 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,995 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,997 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:08,999 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,002 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,017 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,020 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,023 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,026 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,028 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,031 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,037 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,040 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,044 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,046 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,051 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,055 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,058 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,060 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,063 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,065 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,070 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,073 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,075 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,078 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,079 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,082 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,087 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,089 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,092 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,095 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,096 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,099 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,102 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,104 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,107 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,109 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,111 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,113 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,115 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,118 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,120 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,122 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,124 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,127 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,130 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,131 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,134 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,136 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,137 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,139 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,144 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,148 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,152 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,161 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,165 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,177 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,192 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,197 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,203 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,211 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,215 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,222 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,226 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,229 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,232 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,237 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,239 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,241 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,244 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,246 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,252 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,255 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,258 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,261 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,262 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,265 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,270 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,273 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,277 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,286 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,290 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,293 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,297 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,298 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,303 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,306 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,309 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,313 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,314 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,341 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,344 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,345 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,347 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,352 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,357 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,359 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,362 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,364 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,369 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,372 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,373 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,375 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,377 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,380 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,381 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,387 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,389 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,391 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,393 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,397 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,398 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,403 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,405 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,408 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,410 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,412 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,413 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,417 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,419 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,421 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,424 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,425 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,426 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,428 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,432 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,434 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,436 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,438 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,440 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,442 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,444 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,447 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,451 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,461 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,462 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,464 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,469 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,472 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,492 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,494 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,496 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,499 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,502 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,506 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,508 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,510 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,511 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,515 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,519 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,520 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,522 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,524 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,527 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,529 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,531 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,535 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,537 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,539 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,542 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,543 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,550 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,552 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,555 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,558 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,562 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,568 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,570 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,573 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,575 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,578 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,580 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,584 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,586 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,587 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,589 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,591 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,594 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,596 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,598 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,600 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,603 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,605 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,607 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,608 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,610 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,612 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,614 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,620 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,622 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,624 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,626 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,629 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,631 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,635 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,637 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,641 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,654 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,661 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,663 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,665 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,668 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,672 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,674 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,675 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,677 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,680 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,680 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,684 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,687 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,689 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,691 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,692 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,696 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,698 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,705 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,705 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,708 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,708 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,712 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,712 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,721 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,722 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,724 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,726 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,727 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,729 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,731 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,736 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,738 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,740 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,741 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,741 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,746 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,751 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,753 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,756 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,757 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,757 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,762 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,764 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,769 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,772 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,774 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,774 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,779 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,780 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,785 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,786 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,788 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,792 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,792 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,797 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,799 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,802 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,803 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,805 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,807 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,809 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,810 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,810 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,810 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,817 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,817 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,817 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,835 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,835 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,840 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,840 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,840 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,840 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,850 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,850 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,869 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,871 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,873 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,892 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,906 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,916 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,918 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,920 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,922 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,923 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,925 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,927 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,929 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,933 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,958 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,960 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,962 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,965 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,967 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,969 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,971 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,973 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,974 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,975 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,977 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,979 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,981 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,985 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,986 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,988 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,990 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,992 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,995 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,997 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:09,999 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,002 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,003 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,005 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,007 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,009 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,011 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,012 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,016 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,018 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,019 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,022 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,028 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,031 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,033 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,036 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,038 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,039 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,040 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,042 - performance_logger - DEBUG - This is a debug message
# 2024-08-30 22:38:10,043 - performance_logger - DEBUG - This is a debug message
# ...
# This is a debug message
# 2024-08-30 22:39:13,380 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,383 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,388 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,400 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,410 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,417 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,423 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,431 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,437 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,445 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,458 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,465 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,470 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,477 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,483 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,487 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,492 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,498 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,501 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,506 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,513 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,519 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,529 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,533 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,538 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,547 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,555 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,604 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,611 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,617 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,620 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,627 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,630 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,634 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,639 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,642 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,648 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,651 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,663 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,669 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,674 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,683 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,687 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,690 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,693 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,715 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,720 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,740 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,747 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,751 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,755 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,760 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,763 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,769 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,774 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,779 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,783 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,787 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,794 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,797 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,801 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,808 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,815 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,819 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,823 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,829 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,833 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,837 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,840 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,847 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,851 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,874 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,880 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,884 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,888 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,895 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,901 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,906 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,913 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,916 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,921 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,925 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,931 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,935 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,939 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,946 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,952 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,959 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,964 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,971 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,975 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,980 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,990 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:13,999 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,003 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,015 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,020 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,025 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,032 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,037 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,042 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,050 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,054 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,057 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,066 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,071 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,074 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,080 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,084 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,088 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,096 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,121 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,128 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,133 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,136 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,140 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2024-08-30 22:39:14,147 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 46
#      43     logger.removeHandler(rotating_handler)
#      45 # Test the function
# ---> 46 benchmark_logging_performance()
#
# Cell In[12], line 28, in benchmark_logging_performance()
#      26 start_time = time.time()
#      27 for i in range(10000):
# ---> 28     logger.debug('This is a debug message')
#      29 end_time = time.time()
#      30 print('Console handler logging time: {} seconds'.format(end_time - start_time))
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1527, in Logger.debug(self, msg, *args, **kwargs)
#    1518 """
#    1519 Log 'msg % args' with severity 'DEBUG'.
#    1520
#    (...)
#    1524 logger.debug("Houston, we have a %s", "thorny problem", exc_info=True)
#    1525 """
#    1526 if self.isEnabledFor(DEBUG):
# -> 1527     self._log(DEBUG, msg, args, **kwargs)
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1684, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1681         exc_info = sys.exc_info()
#    1682 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1683                          exc_info, func, extra, sinfo)
# -> 1684 self.handle(record)
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1700, in Logger.handle(self, record)
#    1698 if isinstance(maybe_record, LogRecord):
#    1699     record = maybe_record
# -> 1700 self.callHandlers(record)
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1762, in Logger.callHandlers(self, record)
#    1760     found = found + 1
#    1761     if record.levelno >= hdlr.level:
# -> 1762         hdlr.handle(record)
#    1763 if not c.propagate:
#    1764     c = None    #break out
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1028, in Handler.handle(self, record)
#    1026 self.acquire()
#    1027 try:
# -> 1028     self.emit(record)
#    1029 finally:
#    1030     self.release()
#
# File c:\Users\anoop\anaconda3\Lib\logging\__init__.py:1163, in StreamHandler.emit(self, record)
#    1161     stream = self.stream
#    1162     # issue 35046: merged two stream.writes into one.
# -> 1163     stream.write(msg + self.terminator)
#    1164     self.flush()
#    1165 except RecursionError:  # See issue 36272
#
# File c:\Users\anoop\anaconda3\Lib\site-packages\ipykernel\iostream.py:662, in OutStream.write(self, string)
#     660     self.pub_thread.schedule(self._flush)
#     661 else:
# --> 662     self._schedule_flush()
#     664 return len(string)
#
# File c:\Users\anoop\anaconda3\Lib\site-packages\ipykernel\iostream.py:559, in OutStream._schedule_flush(self)
#     556 def _schedule_in_thread():
#     557     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 559 self.pub_thread.schedule(_schedule_in_thread)
#
# File c:\Users\anoop\anaconda3\Lib\site-packages\ipykernel\iostream.py:266, in IOPubThread.schedule(self, f)
#     264     self._events.append(f)
#     265     # wake event thread (message content is ignored)
# --> 266     self._event_pipe.send(b"")
#     267 else:
#     268     f()
#
# File c:\Users\anoop\anaconda3\Lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\\backend\\cython\\socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\anoop\anaconda3\Lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# 2. Modify the script to compare the performance of logging with and without message formatting.

# %%
def benchmark_logging_formatting_performance():
    logger = logging.getLogger('formatting_performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler without formatting
    file_handler = logging.FileHandler('performance_no_format.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time without formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # File handler with formatting
    file_handler = logging.FileHandler('performance_with_format.log')
    file_handler.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time with formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

# Test the function
benchmark_logging_formatting_performance()

# %% [markdown]
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.

# %% [markdown]
# #### File: `logging.conf`

# %%
[loggers]
keys=root

[handlers]
keys=fileHandler,consoleHandler

[formatters]
keys=defaultFormatter

[logger_root]
level=DEBUG
handlers=fileHandler,consoleHandler

[handler_fileHandler]
class=FileHandler
level=DEBUG
formatter=defaultFormatter
args=('advanced_logging_app.log', 'a')

[handler_consoleHandler]
class=StreamHandler
level=DEBUG
formatter=defaultFormatter
args=(sys.stdout,)

[formatter_defaultFormatter]
format=%(asctime)s - %(name)s - %(levelname)s - %(message)s

# %% [markdown]
# #### File: `main.py`

# %%
import logging.config

def setup_logging_from_file():
    logging.config.fileConfig('logging.conf')
    logger = logging.getLogger(__name__)
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
setup_logging_from_file()

# %% [markdown]
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
# The modification is already included in the above configuration file.
