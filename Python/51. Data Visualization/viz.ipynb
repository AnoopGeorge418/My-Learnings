# %%
import matplotlib.pyplot as plt

# %%
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)
plt.show()

# %%
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares, linewidth = 3)
ax.set_title('Square Numbers', fontsize = 24)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of value', fontsize = 14)
ax.tick_params(labelsize = 14)
plt.show()

# %%
squares = [1, 4, 9, 16, 25]
input_values = [1, 2, 3, 4, 5]
fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth = 3)
ax.set_title('Square Numbers', fontsize = 24)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of value', fontsize = 14)
ax.tick_params(labelsize = 14)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
squares = [1, 4, 9, 16, 25]
plt.style.use('dark_background')
fig, ax = plt.subplots()
ax.plot(squares, linewidth = 3)
ax.set_title('Square Numbers', fontsize = 24)
ax.set_xlabel('Value', fontsize = 14)
ax.set_ylabel('Square of value', fontsize = 14)
ax.tick_params(labelsize = 14)
plt.show()

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()
ax.scatter(2, 4, s=200)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

# %%
from random import randint

class Die:
    """A class representing a single die."""
    def __init__(self, num_sides=6):
        """Assume a six-sided die."""
        self.num_sides = num_sides
    
    def roll(self):
        """"Return a random value between 1 and number of sides."""
        return randint(1, self.num_sides)

# %%
# Create a D6.
die = Die()

# Make some rolls, and store results in a list.
results = []
for roll_num in range(100):
    result = die.roll()
    results.append(result)
print(results)
# Out:
# [1, 2, 1, 3, 4, 1, 5, 1, 6, 2, 2, 3, 1, 5, 3, 3, 4, 4, 3, 4, 3, 4, 5, 6, 6, 3, 3, 3, 2, 1, 2, 5, 5, 6, 4, 6, 2, 2, 1, 5, 4, 2, 3, 6, 4, 6, 5, 3, 2, 1, 4, 1, 5, 6, 4, 2, 2, 1, 1, 4, 4, 2, 5, 1, 2, 2, 3, 5, 2, 2, 4, 6, 3, 4, 5, 3, 4, 6, 6, 4, 1, 3, 4, 5, 2, 6, 4, 1, 5, 4, 1, 3, 5, 1, 2, 6, 5, 2, 5, 4]

# %%
# Analyze the results.
frequencies = []
poss_results = range(1, die.num_sides+1)
for value in poss_results:
    frequency = results.count(value)
    frequencies.append(frequency)
print(frequencies)
# Out:
# [16, 19, 16, 20, 16, 13]

# %%
! pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\anoop\appdata\roaming\python\python312\site-packages (4.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\anoop\appdata\roaming\python\python312\site-packages (from nbformat) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core in c:\users\anoop\appdata\roaming\python\python312\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=4.1 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jupyter-core->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\anoop\appdata\roaming\python\python312\site-packages (from jupyter-core->nbformat) (306)
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\anoop\AppData\Roaming\Python\Python312\site-packages\nbformat-5.10.4.dist-info due to invalid metadata entry 'name'
